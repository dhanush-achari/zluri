# %% [markdown]
# # Assignment 1 - Data Analysis Movies Dataset

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

# %%
base_df = pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/movie_dataset.csv")

# %%
base_df.sample(10)
# Out:
#       index    budget                genres  \
# 1130   1130  42000000                Comedy
# 1871   1871  25000000         Family Comedy
# 2744   2744         0         Comedy Family
# 2555   2555  13000000       Horror Thriller
# 4795   4795         0                 Drama
# 2950   2950  11000000  Comedy Drama Romance
# 2191   2191  20000000           Documentary
# 3719   3719   3000000                 Drama
# 3394   3394   7000000         Romance Drama
# 1899   1899         0                 Drama
#
#                                   homepage      id  \
# 1130                                   NaN   18480
# 1871                                   NaN    1268
# 2744                                   NaN   15489
# 2555                                   NaN   11442
# 4795                                   NaN  124606
# 2950                                   NaN   63020
# 2191  http://www.capitalismalovestory.com/   22074
# 3719                                   NaN     510
# 3394            http://www.freeheld.movie/  306745
# 1899                                   NaN   17170
#
#                                                keywords original_language  \
# 1130               gay fame mockumentary hollywood lgbt                en
# 1871   holiday france film director chaos clumsy fellow                en
# 2744                                                NaN                en
# 2555  brother sister relationship innocence serial k...                en
# 4795         gang audition police fake homeless actress                en
# 2950  immigration independent film woman director po...                en
# 2191  usa capitalism capitalist wall street criticis...                en
# 3719  individual rebel self-destruction wheelchair l...                en
# 3394    new jersey equality lesbian relationship cancer                en
# 1899                  magazine writer drug fashion show                en
#
#                        original_title  \
# 1130                            Brüno
# 1871               Mr. Bean's Holiday
# 2744                         Snow Day
# 2555          Halloween: Resurrection
# 4795                             Bang
# 2950                 The Perez Family
# 2191         Capitalism: A Love Story
# 3719  One Flew Over the Cuckoo's Nest
# 3394                         Freeheld
# 1899          Bright Lights, Big City
#
#                                                overview  popularity  ...  \
# 1130  Flamboyantly gay Austrian television reporter ...   16.122168  ...
# 1871  Mr. Bean wins a trip to Cannes where he unwitt...   27.683874  ...
# 2744  When a school in upstate New York is snowed in...    7.964289  ...
# 2555  Serial Killer Michael Myers is not finished wi...   11.045593  ...
# 4795  A young woman in L.A. is having a bad day: she...    0.918116  ...
# 2950  In the midst of the Mariel boat lift -- a hurr...    1.187671  ...
# 2191  Michael Moore's Capitalism: A Love Story comes...   10.500980  ...
# 3719  While serving time for insanity at a state men...  127.525581  ...
# 3394  New Jersey car mechanic Stacie Andree and her ...    8.184588  ...
# 1899  A young kid from Kansas moves to New York to w...    2.753501  ...
#
#      runtime                                   spoken_languages    status  \
# 1130    83.0  [{"iso_639_1": "cs", "name": "\u010cesk\u00fd"...  Released
# 1871    90.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2744    89.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2555    94.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4795    98.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2950   113.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2191   120.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3719   133.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 3394   103.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 1899   107.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 1130                                  Borat was so 2006
# 1871                           Disaster has a passport.
# 2744  Roads closed. Schools shut. Rules were made to...
# 2555                            Evil finds its way home
# 4795            Sometimes you've got to break the rules
# 2950    On the way to finding a family, she found love.
# 2191  Ask not what your C.E.O. can do for you, but w...
# 3719            If he's crazy, what does that make you?
# 3394                A true story of love and injustice.
# 1899                                                NaN
#
#                                 title vote_average vote_count  \
# 1130                            Brüno          5.4        518
# 1871               Mr. Bean's Holiday          6.1        663
# 2744                         Snow Day          4.8         51
# 2555          Halloween: Resurrection          4.5        228
# 4795                             Bang          6.0          1
# 2950                 The Perez Family          6.6          9
# 2191         Capitalism: A Love Story          7.0        167
# 3719  One Flew Over the Cuckoo's Nest          8.2       2919
# 3394                         Freeheld          7.1        164
# 1899          Bright Lights, Big City          4.7         28
#
#                                                    cast  \
# 1130  Sacha Baron Cohen Richard Bey Ron Paul Gustaf ...
# 1871  Rowan Atkinson Max Baldry Emma de Caunes Wille...
# 2744  Chevy Chase Chris Elliott Jean Smart Iggy Pop ...
# 2555  Jamie Lee Curtis Brad Loree Busta Rhymes Bianc...
# 4795  Darling Narita Peter Greene Michael Newland Er...
# 2950  Marisa Tomei Alfred Molina Anjelica Huston Cha...
# 2191  Michael Moore Thora Birch William Black Elijah...
# 3719  Jack Nicholson Louise Fletcher Danny DeVito Wi...
# 3394  Julianne Moore Ellen Page Steve Carell Michael...
# 1899  Michael J. Fox Kiefer Sutherland Phoebe Cates ...
#
#                                                    crew           director
# 1130  [{'name': 'Sacha Baron Cohen', 'gender': 2, 'd...      Larry Charles
# 1871  [{'name': 'Tim Bevan', 'gender': 2, 'departmen...    Steve Bendelack
# 2744  [{'name': 'Will McRobb', 'gender': 2, 'departm...         Chris Koch
# 2555  [{'name': 'Robert A. Ferretti', 'gender': 2, '...     Rick Rosenthal
# 4795  [{'name': 'Ash Baron-Cohen', 'gender': 0, 'dep...    Ash Baron-Cohen
# 2950  [{'name': 'Alan Silvestri', 'gender': 2, 'depa...          Mira Nair
# 2191  [{'name': 'Michael Moore', 'gender': 2, 'depar...      Michael Moore
# 3719  [{'name': 'Jane Feinberg', 'gender': 1, 'depar...  Milo\u0161 Forman
# 3394  [{'name': 'Andrew Mondshein', 'gender': 2, 'de...      Peter Sollett
# 1899  [{'name': 'Sydney Pollack', 'gender': 2, 'depa...      James Bridges
#
# [10 rows x 24 columns]

# %% [markdown]
# # Dropping index colum since already specified

# %%
base_df.drop(["index"],axis = 1,inplace=True)

# %%
base_df.head(5)
# Out:
#       budget                                    genres  \
# 0  237000000  Action Adventure Fantasy Science Fiction
# 1  300000000                  Adventure Fantasy Action
# 2  245000000                    Action Adventure Crime
# 3  250000000               Action Crime Drama Thriller
# 4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Examining the data types of each column in the DataFrame

# %%
base_df.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# cast                     object
# crew                     object
# director                 object
# dtype: object

# %%
base_df.shape
# Out:
# (4803, 23)

# %% [markdown]
# # 1. Finding movies having Minimum and Maximum runtime
#
# #### Since the "runtime" column of the Dataframe is of Datatype float there's requirement for a conversion

# %% [markdown]
# ### Movie with Minimum runtime

# %%
base_df['original_title'][base_df['runtime'] == base_df['runtime'].min()]
# Out:
# 1011                                      The Tooth Fairy
# 3112                              Blood Done Sign My Name
# 3669                                 Should've Been Romeo
# 3809                                  How to Fall in Love
# 3953                                           Fort McCoy
# 3992                                            Sardaarji
# 4068                                            Sharkskin
# 4118                               Hum To Mohabbat Karega
# 4205                                             N-Secure
# 4210                                        दिल जो भी कहे
# 4241                                            The Salon
# 4313                                           Below Zero
# 4318                                      Bleeding Hearts
# 4322                                   Sex With Strangers
# 4328                                The Vatican Exorcisms
# 4405                                    Karachi se Lahore
# 4435                            The Horror Network Vol. 1
# 4458                                  Harrison Montgomery
# 4502                                        Water & Power
# 4504                              Light from the Darkroom
# 4553                           America Is Still the Place
# 4558                       Alleluia! The Devil's Carnival
# 4564                             Straight Out of Brooklyn
# 4566                                         Diamond Ruff
# 4569                                       Mutual Friends
# 4571    Rise of the Entrepreneur: The Search for a Bet...
# 4581                                 Gory Gory Hallelujah
# 4584                         Love in the Time of Monsters
# 4611                                         The Big Swap
# 4620                                 Fighting Tommy Riley
# 4633                                          Death Calls
# 4657                                            UnDivided
# 4658                                           The Frozen
# 4662                                       Little Big Top
# 4729                                 Dude Where's My Dog?
# Name: original_title, dtype: object

# %%
base_df[base_df['runtime'] == base_df['runtime'].min() ][['original_title','runtime']]
# Out:
#                                          original_title  runtime
# 1011                                    The Tooth Fairy      0.0
# 3112                            Blood Done Sign My Name      0.0
# 3669                               Should've Been Romeo      0.0
# 3809                                How to Fall in Love      0.0
# 3953                                         Fort McCoy      0.0
# 3992                                          Sardaarji      0.0
# 4068                                          Sharkskin      0.0
# 4118                             Hum To Mohabbat Karega      0.0
# 4205                                           N-Secure      0.0
# 4210                                      दिल जो भी कहे      0.0
# 4241                                          The Salon      0.0
# 4313                                         Below Zero      0.0
# 4318                                    Bleeding Hearts      0.0
# 4322                                 Sex With Strangers      0.0
# 4328                              The Vatican Exorcisms      0.0
# 4405                                  Karachi se Lahore      0.0
# 4435                          The Horror Network Vol. 1      0.0
# 4458                                Harrison Montgomery      0.0
# 4502                                      Water & Power      0.0
# 4504                            Light from the Darkroom      0.0
# 4553                         America Is Still the Place      0.0
# 4558                     Alleluia! The Devil's Carnival      0.0
# 4564                           Straight Out of Brooklyn      0.0
# 4566                                       Diamond Ruff      0.0
# 4569                                     Mutual Friends      0.0
# 4571  Rise of the Entrepreneur: The Search for a Bet...      0.0
# 4581                               Gory Gory Hallelujah      0.0
# 4584                       Love in the Time of Monsters      0.0
# 4611                                       The Big Swap      0.0
# 4620                               Fighting Tommy Riley      0.0
# 4633                                        Death Calls      0.0
# 4657                                          UnDivided      0.0
# 4658                                         The Frozen      0.0
# 4662                                     Little Big Top      0.0
# 4729                               Dude Where's My Dog?      0.0

# %% [markdown]
# # Correction
#
# ### Since some movies have 0 runtime ,seems like their runtime was never entered. So,lets find the movie having second smallest runtime

# %%
smallest = base_df[base_df['runtime'] != 0].nsmallest(1,['runtime'])
smallest[['original_title','runtime']]
# Out:
#      original_title  runtime
# 4466         Vessel     14.0

# %% [markdown]
# ### Movie with Maximum runtime

# %%
base_df['original_title'][base_df['runtime'] == base_df['runtime'].max()].values[0]
# Out:
# 'Carlos'

# %%
base_df[['original_title','runtime']][base_df['runtime'] == base_df['runtime'].max()]
# Out:
#      original_title  runtime
# 2384         Carlos    338.0

# %% [markdown]
# # 2. Top 5 production houses (by budget) and list their top 5 most popular movies, their revenue and vote_average

# %% [markdown]
# ### Lets convert string back to list

# %%
base_df['production_companies'][0]
# Out:
# '[{"name": "Ingenious Film Partners", "id": 289}, {"name": "Twentieth Century Fox Film Corporation", "id": 306}, {"name": "Dune Entertainment", "id": 444}, {"name": "Lightstorm Entertainment", "id": 574}]'

# %%
from ast import literal_eval

# %%
base_df['production_companies'] = base_df['production_companies'].apply(lambda x : literal_eval(x) )

# %%
base_df['production_companies'][0]
# Out:
# [{'name': 'Ingenious Film Partners', 'id': 289},
#  {'name': 'Twentieth Century Fox Film Corporation', 'id': 306},
#  {'name': 'Dune Entertainment', 'id': 444},
#  {'name': 'Lightstorm Entertainment', 'id': 574}]

# %%
base_df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew', 'director'],
#       dtype='object')

# %% [markdown]
# #### Lets create a DataFrame with only necessary columns so that it is cleaner looking

# %%
df_nes = base_df[['budget',
       'original_title','popularity', 'production_companies'
       , 'release_date', 'revenue', 'runtime',
        'status', 'title', 'vote_average',
       'vote_count']]
df_nes.head()
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  300000000  Pirates of the Caribbean: At World's End  139.082615
# 2  245000000                                   Spectre  107.376788
# 3  250000000                     The Dark Knight Rises  112.312950
# 4  260000000                               John Carter   43.926995
#
#                                 production_companies release_date     revenue  \
# 0  [{'name': 'Ingenious Film Partners', 'id': 289...   2009-12-10  2787965087
# 1  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...   2007-05-19   961000000
# 2  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...   2015-10-26   880674609
# 3  [{'name': 'Legendary Pictures', 'id': 923}, {'...   2012-07-16  1084939099
# 4        [{'name': 'Walt Disney Pictures', 'id': 2}]   2012-03-07   284139100
#
#    runtime    status                                     title  vote_average  \
# 0    162.0  Released                                    Avatar           7.2
# 1    169.0  Released  Pirates of the Caribbean: At World's End           6.9
# 2    148.0  Released                                   Spectre           6.3
# 3    165.0  Released                     The Dark Knight Rises           7.6
# 4    132.0  Released                               John Carter           6.1
#
#    vote_count
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124

# %% [markdown]
# #### Lets parse only the production companies and remove other junk

# %%
df_nes['production_companies'] = df_nes['production_companies'].apply(lambda x : [i['name'] for i in x] )
df_nes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          budget                            original_title  popularity  \
# 0     237000000                                    Avatar  150.437577
# 1     300000000  Pirates of the Caribbean: At World's End  139.082615
# 2     245000000                                   Spectre  107.376788
# 3     250000000                     The Dark Knight Rises  112.312950
# 4     260000000                               John Carter   43.926995
# ...         ...                                       ...         ...
# 4798     220000                               El Mariachi   14.269792
# 4799       9000                                 Newlyweds    0.642552
# 4800          0                 Signed, Sealed, Delivered    1.444476
# 4801          0                          Shanghai Calling    0.857008
# 4802          0                         My Date with Drew    1.929883
#
#                                    production_companies release_date  \
# 0     [Ingenious Film Partners, Twentieth Century Fo...   2009-12-10
# 1     [Walt Disney Pictures, Jerry Bruckheimer Films...   2007-05-19
# 2                      [Columbia Pictures, Danjaq, B24]   2015-10-26
# 3     [Legendary Pictures, Warner Bros., DC Entertai...   2012-07-16
# 4                                [Walt Disney Pictures]   2012-03-07
# ...                                                 ...          ...
# 4798                                [Columbia Pictures]   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [Front Street Pictures, Muse Entertainment Ent...   2013-10-13
# 4801                                                 []   2012-05-03
# 4802       [rusty bear entertainment, lucky crow films]   2005-08-05
#
#          revenue  runtime    status                                     title  \
# 0     2787965087    162.0  Released                                    Avatar
# 1      961000000    169.0  Released  Pirates of the Caribbean: At World's End
# 2      880674609    148.0  Released                                   Spectre
# 3     1084939099    165.0  Released                     The Dark Knight Rises
# 4      284139100    132.0  Released                               John Carter
# ...          ...      ...       ...                                       ...
# 4798     2040920     81.0  Released                               El Mariachi
# 4799           0     85.0  Released                                 Newlyweds
# 4800           0    120.0  Released                 Signed, Sealed, Delivered
# 4801           0     98.0  Released                          Shanghai Calling
# 4802           0     90.0  Released                         My Date with Drew
#
#       vote_average  vote_count
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4798           6.6         238
# 4799           5.9           5
# 4800           7.0           6
# 4801           5.7           7
# 4802           6.3          16
#
# [4803 rows x 11 columns]

# %%
lst = df_nes.sort_values('budget',ascending=False).head(5)['production_companies'].to_list()
lst
# Out:
# [['Walt Disney Pictures',
#   'Jerry Bruckheimer Films',
#   'Moving Picture Company (MPC)'],
#  ['Walt Disney Pictures',
#   'Jerry Bruckheimer Films',
#   'Second Mate Productions'],
#  ['Marvel Studios', 'Prime Focus', 'Revolution Sun Studios'],
#  ['DC Comics',
#   'Legendary Pictures',
#   'Warner Bros.',
#   'Bad Hat Harry Productions'],
#  ['Walt Disney Pictures']]

# %% [markdown]
# ### Top 5 production companies based on budget

# %%
for i in lst:
    st=''
    for j in i:
        st+=','+j
    print(st[1:])
# Out:
# Walt Disney Pictures,Jerry Bruckheimer Films,Moving Picture Company (MPC)
# Walt Disney Pictures,Jerry Bruckheimer Films,Second Mate Productions
# Marvel Studios,Prime Focus,Revolution Sun Studios
# DC Comics,Legendary Pictures,Warner Bros.,Bad Hat Harry Productions
# Walt Disney Pictures

# %%
new_df = df_nes.copy()
new_df.head()
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  300000000  Pirates of the Caribbean: At World's End  139.082615
# 2  245000000                                   Spectre  107.376788
# 3  250000000                     The Dark Knight Rises  112.312950
# 4  260000000                               John Carter   43.926995
#
#                                 production_companies release_date     revenue  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...   2009-12-10  2787965087
# 1  [Walt Disney Pictures, Jerry Bruckheimer Films...   2007-05-19   961000000
# 2                   [Columbia Pictures, Danjaq, B24]   2015-10-26   880674609
# 3  [Legendary Pictures, Warner Bros., DC Entertai...   2012-07-16  1084939099
# 4                             [Walt Disney Pictures]   2012-03-07   284139100
#
#    runtime    status                                     title  vote_average  \
# 0    162.0  Released                                    Avatar           7.2
# 1    169.0  Released  Pirates of the Caribbean: At World's End           6.9
# 2    148.0  Released                                   Spectre           6.3
# 3    165.0  Released                     The Dark Knight Rises           7.6
# 4    132.0  Released                               John Carter           6.1
#
#    vote_count
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124

# %% [markdown]
# # Correction
#
# ## Since Top 5 production houses is asked in the question
# #### Let us parse all the production houses
#
# #### production company has no null values

# %%
new_df.isnull().sum()
# Out:
# budget                  0
# original_title          0
# popularity              0
# production_companies    0
# release_date            1
# revenue                 0
# runtime                 2
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# #### Lets first calculate the adjusted budgets and revenue assuming all production houses invest in an equal ratio

# %%
def budget(row):
    x = row['budget']/(len(row['production_companies']) if len(row['production_companies']) != 0 else 1)
    return x
new_df['budget_adjusted'] = new_df.apply(budget , axis=1)

def revenue(row):
    x = row['revenue']/(len(row['production_companies']) if len(row['production_companies']) != 0 else 1)
    return x
new_df['revenue_adjusted'] = new_df.apply(revenue , axis=1)
new_df
# new_df['budget_adjusted'] = new_df.apply(budget , axis=1)
# Out:
#          budget                            original_title  popularity  \
# 0     237000000                                    Avatar  150.437577
# 1     300000000  Pirates of the Caribbean: At World's End  139.082615
# 2     245000000                                   Spectre  107.376788
# 3     250000000                     The Dark Knight Rises  112.312950
# 4     260000000                               John Carter   43.926995
# ...         ...                                       ...         ...
# 4798     220000                               El Mariachi   14.269792
# 4799       9000                                 Newlyweds    0.642552
# 4800          0                 Signed, Sealed, Delivered    1.444476
# 4801          0                          Shanghai Calling    0.857008
# 4802          0                         My Date with Drew    1.929883
#
#                                    production_companies release_date  \
# 0     [Ingenious Film Partners, Twentieth Century Fo...   2009-12-10
# 1     [Walt Disney Pictures, Jerry Bruckheimer Films...   2007-05-19
# 2                      [Columbia Pictures, Danjaq, B24]   2015-10-26
# 3     [Legendary Pictures, Warner Bros., DC Entertai...   2012-07-16
# 4                                [Walt Disney Pictures]   2012-03-07
# ...                                                 ...          ...
# 4798                                [Columbia Pictures]   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [Front Street Pictures, Muse Entertainment Ent...   2013-10-13
# 4801                                                 []   2012-05-03
# 4802       [rusty bear entertainment, lucky crow films]   2005-08-05
#
#          revenue  runtime    status                                     title  \
# 0     2787965087    162.0  Released                                    Avatar
# 1      961000000    169.0  Released  Pirates of the Caribbean: At World's End
# 2      880674609    148.0  Released                                   Spectre
# 3     1084939099    165.0  Released                     The Dark Knight Rises
# 4      284139100    132.0  Released                               John Carter
# ...          ...      ...       ...                                       ...
# 4798     2040920     81.0  Released                               El Mariachi
# 4799           0     85.0  Released                                 Newlyweds
# 4800           0    120.0  Released                 Signed, Sealed, Delivered
# 4801           0     98.0  Released                          Shanghai Calling
# 4802           0     90.0  Released                         My Date with Drew
#
#       vote_average  vote_count  budget_adjusted  revenue_adjusted
# 0              7.2       11800     5.925000e+07      6.969913e+08
# 1              6.9        4500     1.000000e+08      3.203333e+08
# 2              6.3        4466     8.166667e+07      2.935582e+08
# 3              7.6        9106     6.250000e+07      2.712348e+08
# 4              6.1        2124     2.600000e+08      2.841391e+08
# ...            ...         ...              ...               ...
# 4798           6.6         238     2.200000e+05      2.040920e+06
# 4799           5.9           5     9.000000e+03      0.000000e+00
# 4800           7.0           6     0.000000e+00      0.000000e+00
# 4801           5.7           7     0.000000e+00      0.000000e+00
# 4802           6.3          16     0.000000e+00      0.000000e+00
#
# [4803 rows x 13 columns]

# %% [markdown]
# ### letz perform the explode fuction now

# %%
new_df = new_df.explode('production_companies').reset_index()
new_df.head()
# Out:
#    index     budget                            original_title  popularity  \
# 0      0  237000000                                    Avatar  150.437577
# 1      0  237000000                                    Avatar  150.437577
# 2      0  237000000                                    Avatar  150.437577
# 3      0  237000000                                    Avatar  150.437577
# 4      1  300000000  Pirates of the Caribbean: At World's End  139.082615
#
#                      production_companies release_date     revenue  runtime  \
# 0                 Ingenious Film Partners   2009-12-10  2787965087    162.0
# 1  Twentieth Century Fox Film Corporation   2009-12-10  2787965087    162.0
# 2                      Dune Entertainment   2009-12-10  2787965087    162.0
# 3                Lightstorm Entertainment   2009-12-10  2787965087    162.0
# 4                    Walt Disney Pictures   2007-05-19   961000000    169.0
#
#      status                                     title  vote_average  \
# 0  Released                                    Avatar           7.2
# 1  Released                                    Avatar           7.2
# 2  Released                                    Avatar           7.2
# 3  Released                                    Avatar           7.2
# 4  Released  Pirates of the Caribbean: At World's End           6.9
#
#    vote_count  budget_adjusted  revenue_adjusted
# 0       11800       59250000.0      6.969913e+08
# 1       11800       59250000.0      6.969913e+08
# 2       11800       59250000.0      6.969913e+08
# 3       11800       59250000.0      6.969913e+08
# 4        4500      100000000.0      3.203333e+08

# %% [markdown]
# ### Lets drop the index column and rename production_companies to production_house

# %%
new_df.drop(['index'],inplace = True,axis = 1)

# %%
new_df = new_df.rename({'production_companies':'production_house'} ,axis=1)
new_df.head(5)
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  237000000                                    Avatar  150.437577
# 2  237000000                                    Avatar  150.437577
# 3  237000000                                    Avatar  150.437577
# 4  300000000  Pirates of the Caribbean: At World's End  139.082615
#
#                          production_house release_date     revenue  runtime  \
# 0                 Ingenious Film Partners   2009-12-10  2787965087    162.0
# 1  Twentieth Century Fox Film Corporation   2009-12-10  2787965087    162.0
# 2                      Dune Entertainment   2009-12-10  2787965087    162.0
# 3                Lightstorm Entertainment   2009-12-10  2787965087    162.0
# 4                    Walt Disney Pictures   2007-05-19   961000000    169.0
#
#      status                                     title  vote_average  \
# 0  Released                                    Avatar           7.2
# 1  Released                                    Avatar           7.2
# 2  Released                                    Avatar           7.2
# 3  Released                                    Avatar           7.2
# 4  Released  Pirates of the Caribbean: At World's End           6.9
#
#    vote_count  budget_adjusted  revenue_adjusted
# 0       11800       59250000.0      6.969913e+08
# 1       11800       59250000.0      6.969913e+08
# 2       11800       59250000.0      6.969913e+08
# 3       11800       59250000.0      6.969913e+08
# 4        4500      100000000.0      3.203333e+08

# %%
len(new_df['production_house'].unique())
# Out:
# 5018

# %%
new_df['production_house'].value_counts()
# Out:
# Warner Bros.                                   319
# Universal Pictures                             311
# Paramount Pictures                             285
# Twentieth Century Fox Film Corporation         222
# Columbia Pictures                              201
#                                               ...
# El Camino Pictures                               1
# Bueprint Pictures                                1
# Laurel Group                                     1
# New Artists Alliance                             1
# Colorado Office of Film, Television & Media      1
# Name: production_house, Length: 5017, dtype: int64

# %% [markdown]
# # Correction
# ## Top 5 individual production house according budget
# #### Lets groupby using prodution house

# %%
new_df.groupby('production_house').agg({'budget_adjusted':np.sum}).sort_values('budget_adjusted',ascending=False).head(5)
# Out:
#                       budget_adjusted
# production_house
# Warner Bros.             5.444177e+09
# Universal Pictures       4.766465e+09
# Paramount Pictures       4.741777e+09
# Walt Disney Pictures     4.407308e+09
# Columbia Pictures        4.332848e+09

# %% [markdown]
# ### Top 5 movies of each or them based on popularity

# %% [markdown]
# ##### Top 5 of Warner Bros.

# %%
new_df[new_df['production_house']=='Warner Bros.'].nlargest(5,'popularity')[['original_title','popularity','revenue','vote_average']]
# Out:
#                          original_title  popularity     revenue  vote_average
# 365                        Interstellar  724.247784   675120017           8.1
# 504                  Mad Max: Fury Road  434.278564   378858340           7.2
# 263                     The Dark Knight  187.322927  1004558444           8.2
# 369                           Inception  167.583710   825532764           8.1
# 27   Batman v Superman: Dawn of Justice  155.790452   873260194           5.7

# %% [markdown]
# ##### Top 5 of Universal Pictures

# %%
new_df[new_df['production_house']=='Universal Pictures'].nlargest(5,'popularity')[['original_title','popularity','revenue','vote_average']]
# Out:
#        original_title  popularity     revenue  vote_average
# 2087          Minions  875.581305  1156730962           6.4
# 1948  Despicable Me 2  136.886704   970761885           7.0
# 4157             Lucy  115.241998   126546825           6.3
# 2354    Despicable Me  113.858273   543513985           7.1
# 1625   Bruce Almighty  109.684788   484572835           6.4

# %% [markdown]
# #### Top 5 of Paramount Pictures

# %%
new_df[new_df['production_house']=='Paramount Pictures'].nlargest(5,'popularity')[['original_title','popularity','revenue','vote_average']]
# Out:
#                      original_title  popularity     revenue  vote_average
# 363                    Interstellar  724.247784   675120017           8.1
# 418              Terminator Genisys  202.042635   440603537           5.8
# 57                     The Avengers  144.448633  1519557910           7.4
# 10884                 The Godfather  143.659698   245066411           8.4
# 910    Teenage Mutant Ninja Turtles  143.350376   477200000           5.8

# %% [markdown]
# #### Top 5 of Walt Disney Pictures

# %%
new_df[new_df['production_house']=='Walt Disney Pictures'].nlargest(5,'popularity')[['original_title','popularity','revenue','vote_average']]
# Out:
#                                         original_title  popularity  \
# 762  Pirates of the Caribbean: The Curse of the Bla...  271.972889
# 340                                         Big Hero 6  203.734590
# 494                                             Frozen  165.125366
# 36          Pirates of the Caribbean: Dead Man's Chest  145.847379
# 4             Pirates of the Caribbean: At World's End  139.082615
#
#         revenue  vote_average
# 762   655011224           7.5
# 340   652105443           7.8
# 494  1274219009           7.3
# 36   1065659812           7.0
# 4     961000000           6.9

# %% [markdown]
# ##### Top 5 of Columbia Pictures

# %%
new_df[new_df['production_house']=='Columbia Pictures'].nlargest(5,'popularity')[['original_title','popularity','revenue','vote_average']]
# Out:
#          original_title  popularity    revenue  vote_average
# 1403             Pixels  140.849495  243637091           5.6
# 1735               Fury  139.575085  211817906           7.4
# 3731            Chappie  116.700319  104399548           6.6
# 15         Spider-Man 3  115.699814  890871626           5.9
# 1255  The Fifth Element  109.528572  263920180           7.3

# %% [markdown]
# # 3. List the production house for every year from 2000-2016 which has released the most number of movies in that year

# %%
df1 = new_df.copy()
df1['release_date'].head()
# Out:
# 0    2009-12-10
# 1    2009-12-10
# 2    2009-12-10
# 3    2009-12-10
# 4    2007-05-19
# Name: release_date, dtype: object

# %% [markdown]
# #### Lets convert string value to date and parse only the year

# %%
df1['release_date'] = pd.to_datetime(df1['release_date'])
df1['release_year'] = pd.DatetimeIndex(df1['release_date']).year
df1['release_year'].head()
# Out:
# 0    2009.0
# 1    2009.0
# 2    2009.0
# 3    2009.0
# 4    2007.0
# Name: release_year, dtype: float64

# %%
df1.head(5)
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  237000000                                    Avatar  150.437577
# 2  237000000                                    Avatar  150.437577
# 3  237000000                                    Avatar  150.437577
# 4  300000000  Pirates of the Caribbean: At World's End  139.082615
#
#                          production_house release_date     revenue  runtime  \
# 0                 Ingenious Film Partners   2009-12-10  2787965087    162.0
# 1  Twentieth Century Fox Film Corporation   2009-12-10  2787965087    162.0
# 2                      Dune Entertainment   2009-12-10  2787965087    162.0
# 3                Lightstorm Entertainment   2009-12-10  2787965087    162.0
# 4                    Walt Disney Pictures   2007-05-19   961000000    169.0
#
#      status                                     title  vote_average  \
# 0  Released                                    Avatar           7.2
# 1  Released                                    Avatar           7.2
# 2  Released                                    Avatar           7.2
# 3  Released                                    Avatar           7.2
# 4  Released  Pirates of the Caribbean: At World's End           6.9
#
#    vote_count  budget_adjusted  revenue_adjusted  release_year
# 0       11800       59250000.0      6.969913e+08        2009.0
# 1       11800       59250000.0      6.969913e+08        2009.0
# 2       11800       59250000.0      6.969913e+08        2009.0
# 3       11800       59250000.0      6.969913e+08        2009.0
# 4        4500      100000000.0      3.203333e+08        2007.0

# %% [markdown]
# ### production house has null values for empty entries

# %%
df1.isnull().sum()
# Out:
# budget                0
# original_title        0
# popularity            0
# production_house    351
# release_date          1
# revenue               0
# runtime               2
# status                0
# title                 0
# vote_average          0
# vote_count            0
# budget_adjusted       0
# revenue_adjusted      0
# release_year          1
# dtype: int64

# %%
df1.production_house.fillna('',inplace = True)

# %% [markdown]
# #### To get the count of all the production lets binarize each production house using label binarizer

# %%
from sklearn.preprocessing import LabelBinarizer
labelbinarizer = LabelBinarizer()
output = labelbinarizer.fit_transform(df1['production_house'])
df_bin = pd.DataFrame(output,columns=labelbinarizer.classes_)

df_bin.drop('',axis=1,inplace=True) #DROP THE COLUMN HAVING NO PRODUTION HOUSE NAME
df_bin.tail()
# Out:
#        "DIA" Productions GmbH & Co. KG  1.85 Films  10 West Studios  \
# 14023                                0           0                0
# 14024                                0           0                0
# 14025                                0           0                0
# 14026                                0           0                0
# 14027                                0           0                0
#
#        100 Bares  1019 Entertainment  101st Street Films  \
# 14023          0                   0                   0
# 14024          0                   0                   0
# 14025          0                   0                   0
# 14026          0                   0                   0
# 14027          0                   0                   0
#
#        10th Hole Productions  120 Films  120dB Films  \
# 14023                      0          0            0
# 14024                      0          0            0
# 14025                      0          0            0
# 14026                      0          0            0
# 14027                      0          0            0
#
#        13 Ghosts Productions Canada Inc.  ...  rusty bear entertainment  \
# 14023                                  0  ...                         0
# 14024                                  0  ...                         0
# 14025                                  0  ...                         0
# 14026                                  0  ...                         1
# 14027                                  0  ...                         0
#
#        thefyzz  thinkfilm  uFilm  unafilm  verture Films  warner bross Turkey  \
# 14023        0          0      0        0              0                    0
# 14024        0          0      0        0              0                    0
# 14025        0          0      0        0              0                    0
# 14026        0          0      0        0              0                    0
# 14027        0          0      0        0              0                    0
#
#        winchester films  África Filmes  Österreichischer Rundfunk (ORF)
# 14023                 0              0                                0
# 14024                 0              0                                0
# 14025                 0              0                                0
# 14026                 0              0                                0
# 14027                 0              0                                0
#
# [5 rows x 5017 columns]

# %% [markdown]
# #### Merge with df1 and perform groupby on date

# %%
df1 = pd.merge(df1,df_bin,how="outer",left_index=True,right_index=True)
df1 = df1.loc[:,'release_year':]
df1.sort_values("release_year",inplace=True)
df1.head(5)
# Out:
#        release_year  "DIA" Productions GmbH & Co. KG  1.85 Films  \
# 13691        1916.0                                0           0
# 13690        1916.0                                0           0
# 13805        1925.0                                0           0
# 8849         1927.0                                0           0
# 8850         1927.0                                0           0
#
#        10 West Studios  100 Bares  1019 Entertainment  101st Street Films  \
# 13691                0          0                   0                   0
# 13690                0          0                   0                   0
# 13805                0          0                   0                   0
# 8849                 0          0                   0                   0
# 8850                 0          0                   0                   0
#
#        10th Hole Productions  120 Films  120dB Films  ...  \
# 13691                      0          0            0  ...
# 13690                      0          0            0  ...
# 13805                      0          0            0  ...
# 8849                       0          0            0  ...
# 8850                       0          0            0  ...
#
#        rusty bear entertainment  thefyzz  thinkfilm  uFilm  unafilm  \
# 13691                         0        0          0      0        0
# 13690                         0        0          0      0        0
# 13805                         0        0          0      0        0
# 8849                          0        0          0      0        0
# 8850                          0        0          0      0        0
#
#        verture Films  warner bross Turkey  winchester films  África Filmes  \
# 13691              0                    0                 0              0
# 13690              0                    0                 0              0
# 13805              0                    0                 0              0
# 8849               0                    0                 0              0
# 8850               0                    0                 0              0
#
#        Österreichischer Rundfunk (ORF)
# 13691                                0
# 13690                                0
# 13805                                0
# 8849                                 0
# 8850                                 0
#
# [5 rows x 5018 columns]

# %% [markdown]
# #### Only considering values between 2000 - 2016
# #### Also has a null value to be handled

# %%
df1.isnull().any(axis=0)
# THERE IS ONE null Value in release year so lets drop it
# Interpolate could have been used but it may skew the data as we are trying to find the prodution house hence we drop
df1 = df1.dropna(how='any')
# # Always put brackets while comparing with '&' and '|'
df1 = df1[(df1['release_year']>=2001) & (df1['release_year'] <=2016)]
df1
# Out:
#        release_year  "DIA" Productions GmbH & Co. KG  1.85 Films  \
# 3711         2001.0                                0           0
# 3712         2001.0                                0           0
# 3710         2001.0                                0           0
# 3709         2001.0                                0           0
# 3850         2001.0                                0           0
# ...             ...                              ...         ...
# 11422        2016.0                                0           0
# 3696         2016.0                                0           0
# 6796         2016.0                                0           0
# 11497        2016.0                                0           0
# 7013         2016.0                                0           0
#
#        10 West Studios  100 Bares  1019 Entertainment  101st Street Films  \
# 3711                 0          0                   0                   0
# 3712                 0          0                   0                   0
# 3710                 0          0                   0                   0
# 3709                 0          0                   0                   0
# 3850                 0          0                   0                   0
# ...                ...        ...                 ...                 ...
# 11422                0          0                   0                   0
# 3696                 0          0                   0                   0
# 6796                 0          0                   0                   0
# 11497                0          0                   0                   0
# 7013                 0          0                   0                   0
#
#        10th Hole Productions  120 Films  120dB Films  ...  \
# 3711                       0          0            0  ...
# 3712                       0          0            0  ...
# 3710                       0          0            0  ...
# 3709                       0          0            0  ...
# 3850                       0          0            0  ...
# ...                      ...        ...          ...  ...
# 11422                      0          0            0  ...
# 3696                       0          0            0  ...
# 6796                       0          0            0  ...
# 11497                      0          0            0  ...
# 7013                       0          0            0  ...
#
#        rusty bear entertainment  thefyzz  thinkfilm  uFilm  unafilm  \
# 3711                          0        0          0      0        0
# 3712                          0        0          0      0        0
# 3710                          0        0          0      0        0
# 3709                          0        0          0      0        0
# 3850                          0        0          0      0        0
# ...                         ...      ...        ...    ...      ...
# 11422                         0        0          0      0        0
# 3696                          0        0          0      0        0
# 6796                          0        0          0      0        0
# 11497                         0        0          0      0        0
# 7013                          0        0          0      0        0
#
#        verture Films  warner bross Turkey  winchester films  África Filmes  \
# 3711               0                    0                 0              0
# 3712               0                    0                 0              0
# 3710               0                    0                 0              0
# 3709               0                    0                 0              0
# 3850               0                    0                 0              0
# ...              ...                  ...               ...            ...
# 11422              0                    0                 0              0
# 3696               0                    0                 0              0
# 6796               0                    0                 0              0
# 11497              0                    0                 0              0
# 7013               0                    0                 0              0
#
#        Österreichischer Rundfunk (ORF)
# 3711                                 0
# 3712                                 0
# 3710                                 0
# 3709                                 0
# 3850                                 0
# ...                                ...
# 11422                                0
# 3696                                 0
# 6796                                 0
# 11497                                0
# 7013                                 0
#
# [10755 rows x 5018 columns]

# %%
df1 = df1.groupby("release_year").sum()
df1
# Out:
#               "DIA" Productions GmbH & Co. KG  1.85 Films  10 West Studios  \
# release_year
# 2001.0                                      0           0                0
# 2002.0                                      0           0                0
# 2003.0                                      1           0                0
# 2004.0                                      0           0                0
# 2005.0                                      0           0                0
# 2006.0                                      0           0                0
# 2007.0                                      0           0                0
# 2008.0                                      0           0                0
# 2009.0                                      0           0                0
# 2010.0                                      0           1                0
# 2011.0                                      0           0                0
# 2012.0                                      0           0                0
# 2013.0                                      0           0                0
# 2014.0                                      0           0                0
# 2015.0                                      0           0                1
# 2016.0                                      0           0                0
#
#               100 Bares  1019 Entertainment  101st Street Films  \
# release_year
# 2001.0                0                   0                   0
# 2002.0                0                   0                   0
# 2003.0                0                   0                   0
# 2004.0                0                   0                   0
# 2005.0                0                   0                   0
# 2006.0                0                   0                   0
# 2007.0                0                   0                   0
# 2008.0                0                   0                   0
# 2009.0                1                   0                   0
# 2010.0                0                   0                   0
# 2011.0                0                   0                   0
# 2012.0                0                   0                   0
# 2013.0                1                   0                   0
# 2014.0                0                   0                   0
# 2015.0                0                   1                   0
# 2016.0                0                   0                   0
#
#               10th Hole Productions  120 Films  120dB Films  \
# release_year
# 2001.0                            0          0            0
# 2002.0                            0          1            0
# 2003.0                            0          0            0
# 2004.0                            0          0            0
# 2005.0                            0          0            0
# 2006.0                            0          0            0
# 2007.0                            0          0            1
# 2008.0                            0          0            0
# 2009.0                            0          0            0
# 2010.0                            1          0            0
# 2011.0                            0          0            0
# 2012.0                            0          0            1
# 2013.0                            0          0            0
# 2014.0                            0          0            0
# 2015.0                            0          0            0
# 2016.0                            0          0            0
#
#               13 Ghosts Productions Canada Inc.  ...  \
# release_year                                     ...
# 2001.0                                        1  ...
# 2002.0                                        0  ...
# 2003.0                                        0  ...
# 2004.0                                        0  ...
# 2005.0                                        0  ...
# 2006.0                                        0  ...
# 2007.0                                        0  ...
# 2008.0                                        0  ...
# 2009.0                                        0  ...
# 2010.0                                        0  ...
# 2011.0                                        0  ...
# 2012.0                                        0  ...
# 2013.0                                        0  ...
# 2014.0                                        0  ...
# 2015.0                                        0  ...
# 2016.0                                        0  ...
#
#               rusty bear entertainment  thefyzz  thinkfilm  uFilm  unafilm  \
# release_year
# 2001.0                               0        0          0      0        0
# 2002.0                               0        0          0      0        0
# 2003.0                               0        0          0      0        0
# 2004.0                               0        0          0      0        0
# 2005.0                               1        0          0      0        0
# 2006.0                               0        0          1      1        0
# 2007.0                               0        0          1      0        0
# 2008.0                               0        0          0      1        0
# 2009.0                               0        0          0      0        0
# 2010.0                               0        0          0      0        0
# 2011.0                               0        0          0      1        0
# 2012.0                               0        0          0      0        0
# 2013.0                               0        1          0      1        1
# 2014.0                               0        0          0      2        0
# 2015.0                               0        0          0      0        0
# 2016.0                               0        0          0      0        0
#
#               verture Films  warner bross Turkey  winchester films  \
# release_year
# 2001.0                    0                    0                 1
# 2002.0                    0                    0                 0
# 2003.0                    0                    0                 0
# 2004.0                    0                    0                 0
# 2005.0                    0                    0                 0
# 2006.0                    0                    0                 0
# 2007.0                    0                    0                 0
# 2008.0                    1                    0                 0
# 2009.0                    0                    0                 0
# 2010.0                    0                    0                 0
# 2011.0                    0                    0                 0
# 2012.0                    0                    0                 0
# 2013.0                    0                    0                 0
# 2014.0                    0                    0                 0
# 2015.0                    0                    0                 0
# 2016.0                    0                    1                 0
#
#               África Filmes  Österreichischer Rundfunk (ORF)
# release_year
# 2001.0                    0                                0
# 2002.0                    0                                0
# 2003.0                    0                                0
# 2004.0                    0                                1
# 2005.0                    0                                0
# 2006.0                    0                                0
# 2007.0                    0                                0
# 2008.0                    0                                0
# 2009.0                    0                                0
# 2010.0                    0                                0
# 2011.0                    0                                0
# 2012.0                    0                                0
# 2013.0                    0                                0
# 2014.0                    0                                0
# 2015.0                    1                                0
# 2016.0                    0                                0
#
# [16 rows x 5017 columns]

# %% [markdown]
# # Correction
#
#
# #### From the above data above data it is evident that most of the production house / companies produce only 1 movie per year most of the times.
# ### Now let us try to find those that release maximum movies per year

# %%
df_max = pd.DataFrame()
df_max['max_production_houses']=df1.idxmax(axis=1)

# %%
df_max['Number']=df1.max(axis=1)

# %%
df_max[['max_production_houses','Number']]
# Out:
#              max_production_houses  Number
# release_year
# 2001.0                Warner Bros.      15
# 2002.0          Paramount Pictures      15
# 2003.0          Universal Pictures      14
# 2004.0                Warner Bros.      14
# 2005.0          Universal Pictures      15
# 2006.0                Warner Bros.      17
# 2007.0                Warner Bros.      14
# 2008.0            Relativity Media      20
# 2009.0            Relativity Media      19
# 2010.0            Relativity Media      18
# 2011.0           Columbia Pictures      14
# 2012.0            Relativity Media      13
# 2013.0                Warner Bros.      12
# 2014.0                Warner Bros.      11
# 2015.0          Universal Pictures      12
# 2016.0          Universal Pictures      10

# %% [markdown]
# # Correction
#
# ### 1. In the year 2002 , Warner Bros. and Paramount Pictures	produce the same number of pictures
# ### 2. In the year 2015 , Warner Bros. and Universal Pictures		produce the same number of pictures
#
# ### To get the below output we can reorder the columns:
# ####      release_year	production_company_names	title
# #### 0	2001	Warner Bros.	15
# #### 1	2002	Warner Bros.	15
# #### 2	2003	Universal Pictures	14
# #### 3	2004	Warner Bros.	14
# #### 4	2005	Universal Pictures	15
# #### 5	2006	Warner Bros.	17
# #### 6	2007	Warner Bros.	14
# #### 7	2008	Relativity Media	20
# #### 8	2009	Relativity Media	19
# #### 9	2010	Relativity Media	18
# #### 10	2011	Columbia Pictures	14
# #### 11	2012	Relativity Media	13
# #### 12	2013	Warner Bros.	12
# #### 13	2014	Warner Bros.	11
# #### 14	2015	Warner Bros.	12
# #### 15	2016	Universal Pictures	10

# %%
cols = list(df1.columns)
cols.reverse()

# %%
df1 = df1.reindex(columns = cols)

# %%
df_max['max_production_houses']=df1.idxmax(axis=1)
df_max['Number']=df1.max(axis=1)

# %%
df_max[['max_production_houses','Number']]
# Out:
#              max_production_houses  Number
# release_year
# 2001.0                Warner Bros.      15
# 2002.0                Warner Bros.      15
# 2003.0          Universal Pictures      14
# 2004.0                Warner Bros.      14
# 2005.0          Universal Pictures      15
# 2006.0                Warner Bros.      17
# 2007.0                Warner Bros.      14
# 2008.0            Relativity Media      20
# 2009.0            Relativity Media      19
# 2010.0            Relativity Media      18
# 2011.0           Columbia Pictures      14
# 2012.0            Relativity Media      13
# 2013.0                Warner Bros.      12
# 2014.0                Warner Bros.      11
# 2015.0                Warner Bros.      12
# 2016.0          Universal Pictures      10

# %% [markdown]
# # 4. You are going to invest all your life's savings in a production company. You have two choices "Marvel Studios" and "DC Comics". Which company would you bet on? This is an open-ended question. Define your own metrics to measure which one is a better investment opportunity and defend your analysis.

# %%
df_invest = new_df.copy()
df_invest.head(5)
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  237000000                                    Avatar  150.437577
# 2  237000000                                    Avatar  150.437577
# 3  237000000                                    Avatar  150.437577
# 4  300000000  Pirates of the Caribbean: At World's End  139.082615
#
#                          production_house release_date     revenue  runtime  \
# 0                 Ingenious Film Partners   2009-12-10  2787965087    162.0
# 1  Twentieth Century Fox Film Corporation   2009-12-10  2787965087    162.0
# 2                      Dune Entertainment   2009-12-10  2787965087    162.0
# 3                Lightstorm Entertainment   2009-12-10  2787965087    162.0
# 4                    Walt Disney Pictures   2007-05-19   961000000    169.0
#
#      status                                     title  vote_average  \
# 0  Released                                    Avatar           7.2
# 1  Released                                    Avatar           7.2
# 2  Released                                    Avatar           7.2
# 3  Released                                    Avatar           7.2
# 4  Released  Pirates of the Caribbean: At World's End           6.9
#
#    vote_count  budget_adjusted  revenue_adjusted
# 0       11800       59250000.0      6.969913e+08
# 1       11800       59250000.0      6.969913e+08
# 2       11800       59250000.0      6.969913e+08
# 3       11800       59250000.0      6.969913e+08
# 4        4500      100000000.0      3.203333e+08

# %% [markdown]
# #### Creating column for profits of each prodution company
# #### Creating columns for both and marking 1 when they produced a movie else 0

# %%
df_invest['Profit'] = df_invest['revenue_adjusted'] - df_invest['budget_adjusted']
# df_invest['Marvel']=df_invest['production_house'].apply(lambda x : 1 if 'Marvel Studios' == x else 0)
# df_invest['DC']=df_invest['production_house'].apply(lambda x : 1 if 'DC Comics' == x else 0)

# %%
df_invest.sample(5)
# Out:
#          budget    original_title  popularity                production_house  \
# 3163   55000000        Paddington   39.882276                     StudioCanal
# 8841   15000000       Funny Games   15.175289                    Tartan Films
# 12074   3800000      Major Dundee    3.490215   Columbia Pictures Corporation
# 1838   80000000              Nine    9.357734           The Weinstein Company
# 10017  10000000  Reno 911!: Miami    4.207456  Principato-Young Entertainment
#
#       release_date    revenue  runtime    status             title  \
# 3163    2014-11-27  259207227     95.0  Released        Paddington
# 8841    2007-10-20    7938872    112.0  Released       Funny Games
# 12074   1965-04-07      14873    123.0  Released      Major Dundee
# 1838    2009-12-03   53825515    112.0  Released              Nine
# 10017   2007-02-23   20342161     84.0  Released  Reno 911!: Miami
#
#        vote_average  vote_count  budget_adjusted  revenue_adjusted  \
# 3163            7.0         883     6.111111e+06        28800803.0
# 8841            6.3         545     3.750000e+06         1984718.0
# 12074           6.2          38     1.900000e+06            7436.5
# 1838            5.1         165     4.000000e+07        26912757.5
# 10017           5.6          72     1.428571e+06         2906023.0
#
#              Profit
# 3163   2.268969e+07
# 8841  -1.765282e+06
# 12074 -1.892564e+06
# 1838  -1.308724e+07
# 10017  1.477452e+06

# %% [markdown]
# #### Creating df for movies produced by marvel and dc and calculating their profits

# %%
df_marvel = df_invest[df_invest['production_house']=='Marvel Studios']
df_dc = df_invest[df_invest['production_house']=="DC Comics"]

# %% [markdown]
# #### The average popularity profit generated by Marvel and DC per year

# %%
df_marvel['release_date'] = pd.to_datetime(df_marvel['release_date'])
df_marvel['release_year'] = pd.DatetimeIndex(df_marvel['release_date']).year
df_marvelyear = df_marvel.groupby("release_year").agg({'Profit':np.average,'popularity':np.average})
df_marvelyear
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                     Profit  popularity
# release_year
# 2008          2.243011e+08   91.811695
# 2010          4.239333e+08   77.300194
# 2011          2.649482e+08   80.499835
# 2012          6.497790e+08  144.448633
# 2013          7.450057e+08   88.590837
# 2014          3.477994e+08  276.661945
# 2015          3.822233e+08  127.186419
# 2016          1.806609e+08  198.372395

# %%
df_dc['release_date'] = pd.to_datetime(df_dc['release_date'])
df_dc['release_year'] = pd.DatetimeIndex(df_dc['release_date']).year
df_dcyear = df_dc.groupby("release_year").agg({'Profit':np.average,'popularity':np.average})
df_dcyear
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                     Profit  popularity
# release_year
# 1966         -3.444500e+05    9.815394
# 2005          2.347503e+07   74.834381
# 2006          2.004209e+07   71.278296
# 2008          8.020846e+07  101.085743
# 2009          9.209830e+06   64.798873
# 2010          1.566120e+06   33.166832
# 2013         -1.093750e+07   35.117398
# 2014          4.091607e+07   59.547928
# 2016          1.089383e+08  123.014186

# %% [markdown]
# #### To understand their profit pefomance better lets make some visualizations

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
plt.style.use(['seaborn'])

# %%
years = list(range(1966,2017,4))
plt.figure(figsize=(10,5))
plt.plot(df_marvelyear['Profit'],'r-',label="Marvel profit/year",marker='.')
plt.plot(df_dcyear['Profit'],'b-',label="DC profit/year",marker='.')
plt.xticks(years)
plt.xlabel('Years',fontsize=14)
plt.ylabel('Profit in Billions',fontsize=14)
plt.title("Profit VS Years",fontsize=20)

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# # Conclusion 1:
# ### From the above line graph it clearly evident that at present the average profit generated by MARVEL per year is way larger compared to DC. Thus i would hands down invest in MARVEL , as the production house that generates more profits would yeild better RETURNS to me
#
# #### If i was born in the 1960s i might have invested in DC since there was LINEAR growth in profit generated by DC from 1966 - 2005 and also i there was no option for MARVEL

# %%
years = list(range(1966,2017,4))
plt.figure(figsize=(10,5))
plt.plot(df_marvelyear['popularity'],'r-',label="Marvel popularity/year")
plt.plot(df_dcyear['popularity'],'b-',label="DC popularity/year",marker='.')
plt.xticks(years)
plt.xlabel('Years',fontsize=14)
plt.ylabel('Populatrity',fontsize=14)
plt.title("Populatrity VS Years",fontsize=20)

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
plt.figure()
sns.heatmap(df_marvelyear.corr())
# plt.figure()
sns.heatmap(df_invest.corr())
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# # Conclusion 2:
# ## We can see a positive correlation between popularity and profit from the above heatmap. Which simply means as the popularity increases profit also tends to increase. And from the above Popularity VS Years line graph it is evident that the average growth in poppularity MARVEL is higher that DC currently. Hence the profit of MARVEL can also be presumed to  increase in future. Thus yeilding more RETURNS
#
#
# ## I would invest all my lifes savings into Marvel (also a Marvel Fan Boy)
